# %% [markdown]
# # Eval Results Notebook
#
# Interactive notebook for inspecting evaluation pipeline results,
# comparing runs, and generating summary reports.
#
# ## Sections
# 1. Setup & Configuration
# 2. Load Eval Results
# 3. Compare Runs
# 4. Metric Breakdown
# 5. Export Report

# %% [markdown]
# ## 1. Setup & Configuration

# %%
import os
from pathlib import Path

PROJECT_ROOT = Path(os.environ.get("PROJECT_ROOT", ".")).resolve()
print(f"PROJECT_ROOT: {PROJECT_ROOT}")

# %% [markdown]
# ## 2. Load Eval Results
#
# Fetch recent evaluation runs from MLflow.

# %%
# import mlflow
# mlflow.set_tracking_uri(os.environ["MLFLOW_TRACKING_URI"])
# runs = mlflow.search_runs(experiment_names=["eval"], max_results=20)
# runs.head()

# %% [markdown]
# ## 3. Compare Runs
#
# Side-by-side comparison of champion vs challenger eval metrics.

# %%
# champion_run = runs[runs["tags.alias"] == "champion"].iloc[0]
# challenger_run = runs[runs["tags.alias"] == "challenger"].iloc[0]
# print(f"Champion eval_loss: {champion_run['metrics.eval_loss']:.4f}")
# print(f"Challenger eval_loss: {challenger_run['metrics.eval_loss']:.4f}")

# %% [markdown]
# ## 4. Metric Breakdown
#
# Per-metric analysis across evaluation suites.

# %%
# metric_cols = [c for c in runs.columns if c.startswith("metrics.")]
# runs[metric_cols].describe()

# %% [markdown]
# ## 5. Export Report
#
# Generate a summary report for documentation.

# %%
# report_path = PROJECT_ROOT / "artifacts" / "eval_report.md"
# with open(report_path, "w") as f:
#     f.write("# Evaluation Report\n\n")
#     f.write(f"Total runs: {len(runs)}\n")
# print(f"Report saved to {report_path}")
